# %% [markdown]
# <a href="https://colab.research.google.com/github/GarimaMahajan20/SkillBuildDataCamp/blob/main/SkillBuild.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # New Section

# %%
df1=pd.read_csv("/content/EdStatsCountry.csv")
df2= pd.read_csv("/content/EdStatsCountry-Series.csv")

# %%
df3=pd.read_csv("/content/EdStatsData.csv")

# %%
df4=pd.read_csv("/content/EdStatsFootNote.csv")

# %%
df5=pd.read_csv("/content/EdStatsSeries.csv")

# %% [markdown]
# **EdStatCountry**

# %%
df1.head()
# Out:
#   Country Code   Short Name  ... Latest water withdrawal data Unnamed: 31
# 0          ABW        Aruba  ...                          NaN         NaN
# 1          AFG  Afghanistan  ...                         2000         NaN
# 2          AGO       Angola  ...                         2005         NaN
# 3          ALB      Albania  ...                         2006         NaN
# 4          AND      Andorra  ...                          NaN         NaN
#
# [5 rows x 32 columns]

# %%
df1.columns
# Out:
# Index(['Country Code', 'Short Name', 'Table Name', 'Long Name', '2-alpha code',
#        'Currency Unit', 'Special Notes', 'Region', 'Income Group', 'WB-2 code',
#        'National accounts base year', 'National accounts reference year',
#        'SNA price valuation', 'Lending category', 'Other groups',
#        'System of National Accounts', 'Alternative conversion factor',
#        'PPP survey year', 'Balance of Payments Manual in use',
#        'External debt Reporting status', 'System of trade',
#        'Government Accounting concept', 'IMF data dissemination standard',
#        'Latest population census', 'Latest household survey',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest trade data',
#        'Latest water withdrawal data', 'Unnamed: 31'],
#       dtype='object')

# %%
df1.shape
# Out:
# (241, 32)

# %%
df1.describe()
# Out:
#        National accounts reference year  ...  Unnamed: 31
# count                          32.00000  ...          0.0
# mean                         2001.53125  ...          NaN
# std                             5.24856  ...          NaN
# min                          1987.00000  ...          NaN
# 25%                          1996.75000  ...          NaN
# 50%                          2002.00000  ...          NaN
# 75%                          2005.00000  ...          NaN
# max                          2012.00000  ...          NaN
#
# [8 rows x 4 columns]

# %%
df1.isnull().sum()
# Out:
# Country Code                                           0
# Short Name                                             0
# Table Name                                             0
# Long Name                                              0
# 2-alpha code                                           3
# Currency Unit                                         26
# Special Notes                                         96
# Region                                                27
# Income Group                                          27
# WB-2 code                                              1
# National accounts base year                           36
# National accounts reference year                     209
# SNA price valuation                                   44
# Lending category                                      97
# Other groups                                         183
# System of National Accounts                           26
# Alternative conversion factor                        194
# PPP survey year                                       96
# Balance of Payments Manual in use                     60
# External debt Reporting status                       117
# System of trade                                       41
# Government Accounting concept                         80
# IMF data dissemination standard                       60
# Latest population census                              28
# Latest household survey                              100
# Source of most recent Income and expenditure data     81
# Vital registration complete                          130
# Latest agricultural census                            99
# Latest industrial data                               134
# Latest trade data                                     56
# Latest water withdrawal data                          62
# Unnamed: 31                                          241
# dtype: int64

# %%
df1.drop(columns=['Long Name','2-alpha code','Special Notes','WB-2 code','National accounts reference year','Alternative conversion factor','Unnamed: 31'],inplace=True)

# %%
df1.columns
# Out:
# Index(['Country Code', 'Short Name', 'Table Name', 'Currency Unit', 'Region',
#        'Income Group', 'National accounts base year', 'SNA price valuation',
#        'Lending category', 'Other groups', 'System of National Accounts',
#        'PPP survey year', 'Balance of Payments Manual in use',
#        'External debt Reporting status', 'System of trade',
#        'Government Accounting concept', 'IMF data dissemination standard',
#        'Latest population census', 'Latest household survey',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest trade data',
#        'Latest water withdrawal data'],
#       dtype='object')

# %%
df1.head(5)
# Out:
#   Country Code   Short Name  ... Latest trade data Latest water withdrawal data
# 0          ABW        Aruba  ...            2012.0                          NaN
# 1          AFG  Afghanistan  ...            2012.0                         2000
# 2          AGO       Angola  ...               NaN                         2005
# 3          ALB      Albania  ...            2012.0                         2006
# 4          AND      Andorra  ...            2006.0                          NaN
#
# [5 rows x 25 columns]

# %%
df1.set_index("Table Name" , inplace=True)
df1.head()
# Out:
#             Country Code  ... Latest water withdrawal data
# Table Name                ...
# Aruba                ABW  ...                          NaN
# Afghanistan          AFG  ...                         2000
# Angola               AGO  ...                         2005
# Albania              ALB  ...                         2006
# Andorra              AND  ...                          NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# **EdStatsCountry_Series**

# %%
df2.head()
# Out:
#   CountryCode  ... Unnamed: 3
# 0         ABW  ...        NaN
# 1         ABW  ...        NaN
# 2         AFG  ...        NaN
# 3         AFG  ...        NaN
# 4         AFG  ...        NaN
#
# [5 rows x 4 columns]

# %%
df2.columns
# Out:
# Index(['CountryCode', 'SeriesCode', 'DESCRIPTION', 'Unnamed: 3'], dtype='object')

# %%
df2.drop(columns=['Unnamed: 3'],inplace=True)
df2.head()
# Out:
#   CountryCode  ...                                        DESCRIPTION
# 0         ABW  ...  Data sources : United Nations World Population...
# 1         ABW  ...  Data sources: United Nations World Population ...
# 2         AFG  ...  Data sources: United Nations World Population ...
# 3         AFG  ...                 Estimates are based on regression.
# 4         AFG  ...  Data sources : United Nations World Population...
#
# [5 rows x 3 columns]

# %%
df2.isnull().sum()
# Out:
# CountryCode    0
# SeriesCode     0
# DESCRIPTION    0
# dtype: int64

# %% [markdown]
# **EdStatsData**

# %%
df3.head()
# Out:
#   Country Name Country Code  ... 2100 Unnamed: 69
# 0   Arab World          ARB  ...  NaN         NaN
# 1   Arab World          ARB  ...  NaN         NaN
# 2   Arab World          ARB  ...  NaN         NaN
# 3   Arab World          ARB  ...  NaN         NaN
# 4   Arab World          ARB  ...  NaN         NaN
#
# [5 rows x 70 columns]

# %%
df3.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045',
#        '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
#        '2095', '2100', 'Unnamed: 69'],
#       dtype='object')

# %%
df3.drop(columns=['2017','2020', '2025', '2030', '2035', '2040', '2045',
       '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
       '2095', '2100', 'Unnamed: 69'],inplace=True)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
f,ax = plt.subplots(figsize=(15, 15))
sns.heatmap(df3.corr(), annot=False, linewidths=.3, fmt= '.1f',ax=ax)
plt.show()

# %%
df3.head()
# Out:
#   Country Name Country Code  ... 2015 2016
# 0   Arab World          ARB  ...  NaN  NaN
# 1   Arab World          ARB  ...  NaN  NaN
# 2   Arab World          ARB  ...  NaN  NaN
# 3   Arab World          ARB  ...  NaN  NaN
# 4   Arab World          ARB  ...  NaN  NaN
#
# [5 rows x 51 columns]

# %%
df3.isnull().sum()
# Out:
# Country Name           0
# Country Code           0
# Indicator Name         0
# Indicator Code         0
# 1970              814642
# 1971              851393
# 1972              851311
# 1973              851385
# 1974              851200
# 1975              799624
# 1976              849447
# 1977              849356
# 1978              849354
# 1979              850121
# 1980              797808
# 1981              848153
# 1982              849419
# 1983              848470
# 1984              848324
# 1985              796634
# 1986              847558
# 1987              848289
# 1988              848378
# 1989              849390
# 1990              762525
# 1991              812493
# 1992              811387
# 1993              811137
# 1994              809468
# 1995              755569
# 1996              810123
# 1997              813477
# 1998              802016
# 1999              768091
# 2000              710254
# 2001              763421
# 2002              762725
# 2003              756567
# 2004              758116
# 2005              702822
# 2006              746618
# 2007              749658
# 2008              752543
# 2009              744822
# 2010              644488
# 2011              740918
# 2012              739666
# 2013              749421
# 2014              773141
# 2015              755872
# 2016              870470
# dtype: int64

# %%
df3.groupby('Indicator Code').count()
# Out:
#                              Country Name  Country Code  ...  2015  2016
# Indicator Code                                           ...
# BAR.NOED.1519.FE.ZS                   242           242  ...     0     0
# BAR.NOED.1519.ZS                      242           242  ...     0     0
# BAR.NOED.15UP.FE.ZS                   242           242  ...     0     0
# BAR.NOED.15UP.ZS                      242           242  ...     0     0
# BAR.NOED.2024.FE.ZS                   242           242  ...     0     0
# ...                                   ...           ...  ...   ...   ...
# UIS.XUNIT.USCONST.3.FSGOV             242           242  ...     0     0
# UIS.XUNIT.USCONST.4.FSGOV             242           242  ...     0     0
# UIS.XUNIT.USCONST.56.FSGOV            242           242  ...     0     0
# XGDP.23.FSGOV.FDINSTADM.FFD           242           242  ...     1     0
# XGDP.56.FSGOV.FDINSTADM.FFD           242           242  ...     1     0
#
# [3665 rows x 50 columns]

# %%
df3.shape
# Out:
# (886930, 51)

# %% [markdown]
# **EdStatsFootNote**

# %%
df4.head()
# Out:
#   CountryCode      SeriesCode    Year          DESCRIPTION  Unnamed: 4
# 0         ABW  SE.PRE.ENRL.FE  YR2001  Country estimation.         NaN
# 1         ABW  SE.TER.TCHR.FE  YR2005  Country estimation.         NaN
# 2         ABW  SE.PRE.TCHR.FE  YR2000  Country estimation.         NaN
# 3         ABW  SE.SEC.ENRL.GC  YR2004  Country estimation.         NaN
# 4         ABW     SE.PRE.TCHR  YR2006  Country estimation.         NaN

# %%
df4.columns
# Out:
# Index(['CountryCode', 'SeriesCode', 'Year', 'DESCRIPTION', 'Unnamed: 4'], dtype='object')

# %%
df4.drop(columns=['Unnamed: 4'],inplace=True)
df4.head()
# Out:
#   CountryCode      SeriesCode    Year          DESCRIPTION
# 0         ABW  SE.PRE.ENRL.FE  YR2001  Country estimation.
# 1         ABW  SE.TER.TCHR.FE  YR2005  Country estimation.
# 2         ABW  SE.PRE.TCHR.FE  YR2000  Country estimation.
# 3         ABW  SE.SEC.ENRL.GC  YR2004  Country estimation.
# 4         ABW     SE.PRE.TCHR  YR2006  Country estimation.

# %% [markdown]
# **EdStatsSeries**

# %%
df5.head()
# Out:
#            Series Code       Topic  ... License Type Unnamed: 20
# 0  BAR.NOED.1519.FE.ZS  Attainment  ...          NaN         NaN
# 1     BAR.NOED.1519.ZS  Attainment  ...          NaN         NaN
# 2  BAR.NOED.15UP.FE.ZS  Attainment  ...          NaN         NaN
# 3     BAR.NOED.15UP.ZS  Attainment  ...          NaN         NaN
# 4  BAR.NOED.2024.FE.ZS  Attainment  ...          NaN         NaN
#
# [5 rows x 21 columns]

# %%
df5.isnull().sum()
# Out:
# Series Code                               0
# Topic                                     0
# Indicator Name                            0
# Short definition                       1509
# Long definition                           0
# Unit of measure                        3665
# Periodicity                            3566
# Base Period                            3351
# Other notes                            3113
# Aggregation method                     3618
# Limitations and exceptions             3651
# Notes from original source             3665
# General comments                       3651
# Source                                    0
# Statistical concept and methodology    3642
# Development relevance                  3662
# Related source links                   3450
# Other web links                        3665
# Related indicators                     3665
# License Type                           3665
# Unnamed: 20                            3665
# dtype: int64

# %%
df5.shape
# Out:
# (3665, 21)

# %%
df5.columns
# Out:
# Index(['Series Code', 'Topic', 'Indicator Name', 'Short definition',
#        'Long definition', 'Unit of measure', 'Periodicity', 'Base Period',
#        'Other notes', 'Aggregation method', 'Limitations and exceptions',
#        'Notes from original source', 'General comments', 'Source',
#        'Statistical concept and methodology', 'Development relevance',
#        'Related source links', 'Other web links', 'Related indicators',
#        'License Type', 'Unnamed: 20'],
#       dtype='object')

# %%
df5.drop(columns=['Unit of measure', 'Periodicity', 'Base Period',
       'Other notes', 'Aggregation method', 'Limitations and exceptions',
       'Notes from original source', 'General comments','Source','Statistical concept and methodology', 'Development relevance',
       'Related source links', 'Other web links', 'Related indicators',
       'License Type', 'Unnamed: 20'],inplace=True)
df5.head()
# Out:
#            Series Code  ...                                    Long definition
# 0  BAR.NOED.1519.FE.ZS  ...  Percentage of female population age 15-19 with...
# 1     BAR.NOED.1519.ZS  ...  Percentage of population age 15-19 with no edu...
# 2  BAR.NOED.15UP.FE.ZS  ...  Percentage of female population age 15+ with n...
# 3     BAR.NOED.15UP.ZS  ...  Percentage of population age 15+ with no educa...
# 4  BAR.NOED.2024.FE.ZS  ...  Percentage of female population age 20-24 with...
#
# [5 rows x 5 columns]

# %%
countries_income = df1["Country Code"].unique()
countries_income = pd.DataFrame({"Country_Code" : df1["Country Code"].unique(), "Name" : df1["Short Name"], "Region" : df1["Region"], "Income_group" : df1["Income Group"]})
countries_income.to_csv("countries_income.csv")
countries_income.head()
# Out:
#             Country_Code  ...          Income_group
# Table Name                ...
# Aruba                ABW  ...  High income: nonOECD
# Afghanistan          AFG  ...            Low income
# Angola               AGO  ...   Upper middle income
# Albania              ALB  ...   Upper middle income
# Andorra              AND  ...  High income: nonOECD
#
# [5 rows x 4 columns]

# %%
df3["Country Name"].describe()
# Out:
# count     886930
# unique       242
# top       Zambia
# freq        3665
# Name: Country Name, dtype: object

# %%
df3["Indicator Name"].describe()
# Out:
# count                                                886930
# unique                                                 3665
# top       Expenditure on post-secondary non-tertiary as ...
# freq                                                    242
# Name: Indicator Name, dtype: object

# %%
countries = df3["Country Name"].unique()
countries = pd.DataFrame({"Country Name" : df3["Country Name"].unique()})
countries.to_csv("countries.csv")
countries.head()
# Out:
#                                   Country Name
# 0                                   Arab World
# 1                          East Asia & Pacific
# 2  East Asia & Pacific (excluding high income)
# 3                                    Euro area
# 4                        Europe & Central Asia

# %%
data_plus_country = pd.merge(df3,countries_income, left_on='Country Code', right_on='Country_Code')
data_plus_country.head()
# Out:
#   Country Name Country Code  ... Region Income_group
# 0   Arab World          ARB  ...    NaN          NaN
# 1   Arab World          ARB  ...    NaN          NaN
# 2   Arab World          ARB  ...    NaN          NaN
# 3   Arab World          ARB  ...    NaN          NaN
# 4   Arab World          ARB  ...    NaN          NaN
#
# [5 rows x 55 columns]

# %%
data_column_reduced = data_plus_country.filter(items=['Region', 'Country Name', 'Country Code', 'Income_group', 'Indicator Name', 'Indicator Code', '1990','2000','2010', '2015'])
data_column_reduced.head()
# Out:
#   Region Country Name Country Code  ...       2000       2010 2015
# 0    NaN   Arab World          ARB  ...        NaN        NaN  NaN
# 1    NaN   Arab World          ARB  ...        NaN        NaN  NaN
# 2    NaN   Arab World          ARB  ...        NaN        NaN  NaN
# 3    NaN   Arab World          ARB  ...        NaN        NaN  NaN
# 4    NaN   Arab World          ARB  ...  77.245682  85.211998  NaN
#
# [5 rows x 10 columns]

# %%
data_column_reduced.Income_group.unique()
# Out:
# array(['Low income', 'Upper middle income', 'High income: nonOECD',
#        'Lower middle income', 'High income: OECD'], dtype=object)

# %%
#Select Countries with upper middle income and high income
incomes_to_keep = ['Upper middle income', 'High income: nonOECD', 'High income: OECD']
data_reduced_income = data_column_reduced[data_column_reduced.Income_group.isin(incomes_to_keep)]
data_reduced_income.head()
# Out:
#                       Region Country Name  ...       2010 2015
# 95290  Europe & Central Asia      Albania  ...        NaN  NaN
# 95291  Europe & Central Asia      Albania  ...        NaN  NaN
# 95292  Europe & Central Asia      Albania  ...        NaN  NaN
# 95293  Europe & Central Asia      Albania  ...        NaN  NaN
# 95294  Europe & Central Asia      Albania  ...  91.033867  NaN
#
# [5 rows x 10 columns]

# %% [markdown]
# Select indicators for INTERNET Data

# %%
codes_to_keep = ['IT.NET.USER.P2', 'IT.CMP.PCMP.P2']
data_reduced_itc = data_reduced_income[data_reduced_income['Indicator Code'].isin(codes_to_keep)]
data_reduced_itc.head()
# Out:
#                             Region    Country Name  ...  2010       2015
# 96665        Europe & Central Asia         Albania  ...  45.0  63.252933
# 97374        Europe & Central Asia         Albania  ...   NaN        NaN
# 100330  Middle East & North Africa         Algeria  ...  12.5  38.200000
# 101039  Middle East & North Africa         Algeria  ...   NaN        NaN
# 103995         East Asia & Pacific  American Samoa  ...   NaN        NaN
#
# [5 rows x 10 columns]

# %%
data_reduced_itc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 260 entries, 96665 to 867024
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          260 non-null    object
#  1   Country Name    260 non-null    object
#  2   Country Code    260 non-null    object
#  3   Income_group    260 non-null    object
#  4   Indicator Name  260 non-null    object
#  5   Indicator Code  260 non-null    object
#  6   1990            171 non-null    float64
#  7   2000            212 non-null    float64
#  8   2010            120 non-null    float64
#  9   2015            120 non-null    float64
# dtypes: float64(4), object(6)
# memory usage: 22.3+ KB

# %%
data_reduced_itc.groupby('Indicator Code').count()
# Out:
#                 Region  Country Name  Country Code  ...  2000  2010  2015
# Indicator Code                                      ...
# IT.CMP.PCMP.P2     130           130           130  ...    95     0     0
# IT.NET.USER.P2     130           130           130  ...   117   120   120
#
# [2 rows x 9 columns]

# %% [markdown]
# IT.NET.USER.P2 Indicator Code for 2015 has 120 out of 130 entries not null
#
# Select the information that seems relevant to answer the problem. Which columns contain information that can be useful to answer the problem of the company?
#
# Indicator Codes can be used to determine the internet users,demographics,education, economics etc. Since,the EdTech Academy provides online training for students, there is no point in expanding the project in countries wherein the use of Internet is very low. By looking at such different indicator codes, one can determine whether to expand the startup in that particular country or not.

# %%
data_completeness = pd.merge(df3,countries_income, left_on='Country Code', right_on='Country_Code')
data_completeness.head()
# Out:
#   Country Name Country Code  ... Region Income_group
# 0   Arab World          ARB  ...    NaN          NaN
# 1   Arab World          ARB  ...    NaN          NaN
# 2   Arab World          ARB  ...    NaN          NaN
# 3   Arab World          ARB  ...    NaN          NaN
# 4   Arab World          ARB  ...    NaN          NaN
#
# [5 rows x 55 columns]

# %%
data_completeness = data_completeness[data_completeness.Income_group.notnull()]
data_completeness.head()
# Out:
#       Country Name Country Code  ...      Region Income_group
# 91625  Afghanistan          AFG  ...  South Asia   Low income
# 91626  Afghanistan          AFG  ...  South Asia   Low income
# 91627  Afghanistan          AFG  ...  South Asia   Low income
# 91628  Afghanistan          AFG  ...  South Asia   Low income
# 91629  Afghanistan          AFG  ...  South Asia   Low income
#
# [5 rows x 55 columns]

# %%
data_completeness['2013'].plot()

# %% [markdown]
# Determine orders of magnitude of traditional statistical indicators for different geographical areas and countries of the world (average / median / standard deviation by country and continent or geographical block).

# %%
df=data_completeness.groupby('Name').describe()
df.head()
# Out:
#                  1970                ...          2016
#                 count          mean  ...           75%           max
# Name                                 ...
# Afghanistan     523.0  6.872726e+06  ...  1.287587e+07  6.588225e+10
# Albania         409.0  2.787310e+04  ...  1.825790e+05  3.412638e+10
# Algeria         416.0  1.174261e+08  ...  1.319167e+07  6.108142e+11
# American Samoa    2.0  1.364726e+04  ...  1.336805e+08  6.580000e+08
# Andorra          41.0  2.686961e+07  ...  1.000000e+02  3.298477e+09
#
# [5 rows x 376 columns]

# %%
dfn=df.filter((('1970','mean'),('1971','mean')),axis=1)

# %%
plt.figure(figsize=(15,15))
dfn.head(10).plot()

# %%
data_completeness.head()
# Out:
#       Country Name Country Code  ...      Region Income_group
# 91625  Afghanistan          AFG  ...  South Asia   Low income
# 91626  Afghanistan          AFG  ...  South Asia   Low income
# 91627  Afghanistan          AFG  ...  South Asia   Low income
# 91628  Afghanistan          AFG  ...  South Asia   Low income
# 91629  Afghanistan          AFG  ...  South Asia   Low income
#
# [5 rows x 55 columns]

# %%
data_completeness.describe()
# Out:
#                1970          1971  ...          2015          2016
# count  6.855300e+04  3.163900e+04  ...  1.291260e+05  1.565200e+04
# mean   3.309056e+08  7.590566e+08  ...  4.294475e+09  3.640192e+10
# std    2.290133e+10  3.505489e+10  ...  1.798039e+11  5.358973e+11
# min   -1.435564e+00 -1.594625e+00  ... -2.467847e+00 -1.797539e+00
# 25%    8.000000e-01  8.196820e+00  ...  4.000000e-01  1.800000e+01
# 50%    5.700000e+00  5.628730e+01  ...  5.113000e+01  5.960130e+03
# 75%    5.305532e+01  3.287700e+04  ...  5.999025e+04  5.125808e+05
# max    4.779684e+12  4.937198e+12  ...  1.985273e+13  2.145097e+13
#
# [8 rows x 47 columns]

# %% [markdown]
# **PISA scores**

# %%
df3.set_index("Country Name")
# Out:
#              Country Code  ... 2016
# Country Name               ...
# Arab World            ARB  ...  NaN
# Arab World            ARB  ...  NaN
# Arab World            ARB  ...  NaN
# Arab World            ARB  ...  NaN
# Arab World            ARB  ...  NaN
# ...                   ...  ...  ...
# Zimbabwe              ZWE  ...  NaN
# Zimbabwe              ZWE  ...  NaN
# Zimbabwe              ZWE  ...  NaN
# Zimbabwe              ZWE  ...  NaN
# Zimbabwe              ZWE  ...  NaN
#
# [886930 rows x 50 columns]

# %%
pisa_df=df3.filter(('Country Name','2000', '2003', '2006', '2009', '2012', '2015', '2018'))

# %%
filtered_pisa_df=pisa_df.groupby('Country Name').describe()

# %%
filtered_pisa_df=filtered_pisa_df.filter((('2000','mean'),('2003','mean'),('2006','mean'),('2009','mean'),('2012','mean'),('2015','mean'),('2018','mean')))

# %% [markdown]
# Plotting mean PISA( Program for International Student Assessment) values for Afghanistan, Albania, Algeria,American Samoa and Andorra
#
# PISA assesses the extent to which students near the end of compulsory education have acquired some of the knowledge and skills that are essential for full participation in society. It focuses on student competencies in the key subject areas of reading, mathematics and science.

# %%
filtered_pisa_df.head(5).plot()

# %% [markdown]
# Which country have high customer potential for our services?

# %%
data_reduced_itc.head()
# Out:
#                             Region    Country Name  ...  2010       2015
# 96665        Europe & Central Asia         Albania  ...  45.0  63.252933
# 97374        Europe & Central Asia         Albania  ...   NaN        NaN
# 100330  Middle East & North Africa         Algeria  ...  12.5  38.200000
# 101039  Middle East & North Africa         Algeria  ...   NaN        NaN
# 103995         East Asia & Pacific  American Samoa  ...   NaN        NaN
#
# [5 rows x 10 columns]

# %%
dfx=data_reduced_itc.nlargest(10,['2015'])
dfx.head()
# Out:
#                        Region Country Name  ...   2010      2015
# 169965          North America      Bermuda  ...  84.21  98.32361
# 408190  Europe & Central Asia      Iceland  ...  93.39  98.20000
# 510810  Europe & Central Asia   Luxembourg  ...  90.62  97.33410
# 107660  Europe & Central Asia      Andorra  ...  81.00  96.91000
# 624425  Europe & Central Asia       Norway  ...  93.39  96.81030
#
# [5 rows x 10 columns]

# %% [markdown]
# These countries have the largest number of internet users(per 100 people) in the recent years( Year 2015). Hence these countries have a high potential for the services of the company
#
# For each of these countries, what will be the evolution of this customerpotential?
# Plot showing variations in number of inernet users per 100 for the countries having highest internet users

# %%
dfx.set_index("Country Name").head().plot(kind="bar")

# %% [markdown]
# In which countries should one set up first?

# %%
data_reduced_itc.nlargest(10,['2015'])
# Out:
#                             Region   Country Name  ...   2010       2015
# 169965               North America        Bermuda  ...  84.21  98.323610
# 408190       Europe & Central Asia        Iceland  ...  93.39  98.200000
# 510810       Europe & Central Asia     Luxembourg  ...  90.62  97.334100
# 107660       Europe & Central Asia        Andorra  ...  81.00  96.910000
# 624425       Europe & Central Asia         Norway  ...  93.39  96.810300
# 503480       Europe & Central Asia  Liechtenstein  ...  80.00  96.641195
# 283580       Europe & Central Asia        Denmark  ...  88.72  96.330500
# 323895       Europe & Central Asia  Faroe Islands  ...  75.20  94.200000
# 144310  Middle East & North Africa        Bahrain  ...  55.00  93.478301
# 565785       Europe & Central Asia         Monaco  ...  75.00  93.363302
#
# [10 rows x 10 columns]

# %% [markdown]
# One should set up first in countrues having high incomes and large number of internet users per 100
